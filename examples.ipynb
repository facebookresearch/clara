# %%
import numpy as np
from simulator import generate_dataset_tiebreaking
from simulator import generate_labeler_confusion_matrix
from simulator import generate_dataset_tiebreaking_different_labeler_cm
from gibbs import ClaraGibbs

# %%
# Simulate a dataset with 1000 items and all labelers share a single confusion matrix
df = generate_dataset_tiebreaking(
    dataset_id=0,
    theta=np.array([0.8, 0.2]),
    psi=np.array([[0.9, 0.1], [0.05, 0.95]]),
    num_items=1000,
)

# %%
df.tail(10)
# Out:
#     dataset     id   labelers    ratings true_rating
# 990       0  0_990     [0, 0]     [0, 0]           0
# 991       0  0_991     [0, 0]     [0, 0]           0
# 992       0  0_992  [0, 0, 0]  [0, 1, 0]           0
# 993       0  0_993     [0, 0]     [0, 0]           0
# 994       0  0_994     [0, 0]     [0, 0]           0
# 995       0  0_995  [0, 0, 0]  [1, 0, 0]           0
# 996       0  0_996     [0, 0]     [0, 0]           0
# 997       0  0_997  [0, 0, 0]  [1, 0, 0]           0
# 998       0  0_998     [0, 0]     [0, 0]           0
# 999       0  0_999     [0, 0]     [0, 0]           0

# %%
# Fit the model
model = ClaraGibbs(burn_in=100, num_samples=100, sample_lag=3)
model.fit(A=1, R=2, ratings=np.array(df.ratings))
# Out:
# INFO:gibbs:Fitting ...
# INFO:gibbs: N = 1000
# INFO:gibbs: R = 2
# INFO:gibbs: A = 1
# INFO:gibbs: C = 0
# INFO:gibbs:Initializing ...
# INFO:gibbs:Getting priors ...
# INFO:gibbs:  theta_scale = 1.0
# INFO:gibbs:  theta_mean = [0.72735632 0.27264368]
# INFO:gibbs: theta_prior = dimension = 2. scale = 1.0. mean = [0.72735632 0.27264368].
# INFO:gibbs:  psi_scale = [1.0, 1.0]
# INFO:gibbs:  psi_mean = [[0.75, 0.25], [0.25, 0.75]]
# INFO:gibbs: psi_prior = [dimension = 2. scale = 1.0. mean = [0.75 0.25]., dimension = 2. scale = 1.0. mean = [0.25 0.75].]
# INFO:gibbs: phi_prior = None
# INFO:gibbs:  llh = -1153.3978848368724
# INFO:gibbs:  theta = prior: dimension = 2. scale = 1.0. mean = [0.72735632 0.27264368].. data: counts: {0: 770, 1: 230}. count_sum = 1000.. posterior: [0.7699573989229163, 0.23004260107708385]
# INFO:gibbs:  psi[0][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 1540, 1: 132}. count_sum = 1672.. posterior: [0.9209503885236103, 0.07904961147638973]
# INFO:gibbs:  psi[0][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {1: 460, 0: 41}. count_sum = 501.. posterior: [0.08217131474103585, 0.9178286852589641]
# INFO:gibbs:Sampling ...
# INFO:gibbs: Iter 0 / 400
# INFO:gibbs:  n_changes = 22 / 1000
# INFO:gibbs:  llh = -1200.5291532977835
# INFO:gibbs:  theta = prior: dimension = 2. scale = 1.0. mean = [0.72735632 0.27264368].. data: counts: {0: 786, 1: 214}. count_sum = 1000.. posterior: [0.7859414149069321, 0.21405858509306785]
# INFO:gibbs:  psi[0][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 1547, 1: 168}. count_sum = 1715.. posterior: [0.9019522144522144, 0.09804778554778555]
# INFO:gibbs:  psi[0][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {1: 424, 0: 34}. count_sum = 458.. posterior: [0.07461873638344227, 0.9253812636165577]
# INFO:gibbs: Iter 40 / 400
# INFO:gibbs:  n_changes = 35 / 1000
# INFO:gibbs:  llh = -1190.22918661742
# INFO:gibbs:  theta = prior: dimension = 2. scale = 1.0. mean = [0.72735632 0.27264368].. data: counts: {0: 794, 1: 206}. count_sum = 1000.. posterior: [0.7939334228989402, 0.20606657710105988]
# INFO:gibbs:  psi[0][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 1557, 1: 180}. count_sum = 1737.. posterior: [0.8962888377445339, 0.10371116225546605]
# INFO:gibbs:  psi[0][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {1: 412, 0: 24}. count_sum = 436.. posterior: [0.055491990846681924, 0.9445080091533181]
# INFO:gibbs: Iter 80 / 400
# INFO:gibbs:  n_changes = 46 / 1000
# INFO:gibbs:  llh = -1223.8214102982456
# INFO:gibbs:  theta = prior: dimension = 2. scale = 1.0. mean = [0.72735632 0.27264368].. data: counts: {0: 792, 1: 208}. count_sum = 1000.. posterior: [0.7919354209009382, 0.20806457909906187]
# INFO:gibbs:  psi[0][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 1546, 1: 181}. count_sum = 1727.. posterior: [0.8951099537037037, 0.1048900462962963]
# INFO:gibbs:  psi[0][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {1: 411, 0: 35}. count_sum = 446.. posterior: [0.07885906040268456, 0.9211409395973155]
# INFO:gibbs: Iter 120 / 400
# INFO:gibbs:  n_changes = 44 / 1000
# INFO:gibbs:  llh = -1210.341577781031
# INFO:gibbs:  theta = prior: dimension = 2. scale = 1.0. mean = [0.72735632 0.27264368].. data: counts: {0: 800, 1: 200}. count_sum = 1000.. posterior: [0.7999274288929462, 0.20007257110705387]
# INFO:gibbs:  psi[0][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 1557, 1: 193}. count_sum = 1750.. posterior: [0.8896344945745288, 0.11036550542547116]
# INFO:gibbs:  psi[0][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {1: 399, 0: 24}. count_sum = 423.. posterior: [0.057193396226415096, 0.9428066037735849]
# INFO:gibbs: Iter 160 / 400
# INFO:gibbs:  n_changes = 40 / 1000
# INFO:gibbs:  llh = -1200.278929566473
# INFO:gibbs:  theta = prior: dimension = 2. scale = 1.0. mean = [0.72735632 0.27264368].. data: counts: {0: 793, 1: 207}. count_sum = 1000.. posterior: [0.7929344218999392, 0.20706557810006088]
# INFO:gibbs:  psi[0][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 1553, 1: 179}. count_sum = 1732.. posterior: [0.8965666474321985, 0.1034333525678015]
# INFO:gibbs:  psi[0][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {1: 413, 0: 28}. count_sum = 441.. posterior: [0.06391402714932126, 0.9360859728506787]
# INFO:gibbs: Iter 200 / 400
# INFO:gibbs:  n_changes = 36 / 1000
# INFO:gibbs:  llh = -1207.5574553148772
# INFO:gibbs:  theta = prior: dimension = 2. scale = 1.0. mean = [0.72735632 0.27264368].. data: counts: {0: 800, 1: 200}. count_sum = 1000.. posterior: [0.7999274288929462, 0.20007257110705387]
# INFO:gibbs:  psi[0][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 1558, 1: 193}. count_sum = 1751.. posterior: [0.8896974885844748, 0.11030251141552512]
# INFO:gibbs:  psi[0][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {1: 399, 0: 23}. count_sum = 422.. posterior: [0.0549645390070922, 0.9450354609929078]
# INFO:gibbs: Iter 240 / 400
# INFO:gibbs:  n_changes = 53 / 1000
# INFO:gibbs:  llh = -1224.3643463763838
# INFO:gibbs:  theta = prior: dimension = 2. scale = 1.0. mean = [0.72735632 0.27264368].. data: counts: {0: 803, 1: 197}. count_sum = 1000.. posterior: [0.8029244318899492, 0.1970755681100509]
# INFO:gibbs:  psi[0][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 1555, 1: 199}. count_sum = 1754.. posterior: [0.8864672364672365, 0.11353276353276354]
# INFO:gibbs:  psi[0][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {1: 393, 0: 26}. count_sum = 419.. posterior: [0.0625, 0.9375]
# INFO:gibbs: Iter 280 / 400
# INFO:gibbs:  n_changes = 38 / 1000
# INFO:gibbs:  llh = -1179.7965258661084
# INFO:gibbs:  theta = prior: dimension = 2. scale = 1.0. mean = [0.72735632 0.27264368].. data: counts: {0: 781, 1: 219}. count_sum = 1000.. posterior: [0.7809464099119272, 0.21905359008807285]
# INFO:gibbs:  psi[0][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 1546, 1: 155}. count_sum = 1701.. posterior: [0.9087837837837838, 0.09121621621621621]
# INFO:gibbs:  psi[0][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {1: 437, 0: 35}. count_sum = 472.. posterior: [0.07452431289640592, 0.9254756871035941]
# INFO:gibbs: Iter 320 / 400
# INFO:gibbs:  n_changes = 49 / 1000
# INFO:gibbs:  llh = -1244.7675606387274
# INFO:gibbs:  theta = prior: dimension = 2. scale = 1.0. mean = [0.72735632 0.27264368].. data: counts: {0: 787, 1: 213}. count_sum = 1000.. posterior: [0.7869404159059332, 0.21305958409406686]
# INFO:gibbs:  psi[0][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 1539, 1: 180}. count_sum = 1719.. posterior: [0.8952034883720931, 0.10479651162790697]
# INFO:gibbs:  psi[0][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {1: 412, 0: 42}. count_sum = 454.. posterior: [0.09285714285714286, 0.9071428571428571]
# INFO:gibbs: Iter 360 / 400
# INFO:gibbs:  n_changes = 39 / 1000
# INFO:gibbs:  llh = -1213.644931440242
# INFO:gibbs:  theta = prior: dimension = 2. scale = 1.0. mean = [0.72735632 0.27264368].. data: counts: {0: 782, 1: 218}. count_sum = 1000.. posterior: [0.7819454109109282, 0.21805458908907185]
# INFO:gibbs:  psi[0][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 1540, 1: 164}. count_sum = 1704.. posterior: [0.9036656891495601, 0.09633431085043988]
# INFO:gibbs:  psi[0][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {1: 428, 0: 41}. count_sum = 469.. posterior: [0.08776595744680851, 0.9122340425531915]
# INFO:gibbs:Done sampling!

# %%
# Get the prevalence estimate (mean and 95% confidence interval)
model.get_prevalence()
# Out:
# {'mean': [0.7939633929289102, 0.2060366070710899],
#  'ci': [[0.7789484079139252, 0.18708555812004088],
#   [0.8129144418799592, 0.22105159208607486]]}

# %%
# Get the (shared) confusion matrix (mean and 95% confidence interval)
model.get_confusion_matrix(labeler_id=0)
# Out:
# [{'mean': [0.8939925482315203, 0.10600745176847975],
#   'ci': [[0.877224217322873, 0.09350601422319929],
#    [0.9064939857768007, 0.12277578267712702]]},
#  {'mean': [0.06670896246401536, 0.9332910375359846],
#   'ci': [[0.03135612743490523, 0.9020246660521936],
#    [0.09797533394780647, 0.9686438725650948]]}]

# %%
# Simulate 10 different labelers, each with a separate confusion matrix
psi = generate_labeler_confusion_matrix(
    num_labelers=10, psi_mean=[0.9, 0.8], psi_std=[0.1, 0.1])

# %%
# Simulate a dataset with 1000 items and 10 labelers, each labeler has a separate
# confusion matrix as in psi
df2 = generate_dataset_tiebreaking_different_labeler_cm(
    dataset_id=1, theta=np.array([0.8, 0.2]), psi=psi, num_items=1000)

# %%
df2.tail(10)
# Out:
#     dataset     id   labelers    ratings true_rating
# 990       1  1_990     [6, 8]     [0, 0]           0
# 991       1  1_991     [6, 8]     [1, 1]           1
# 992       1  1_992     [1, 4]     [0, 0]           0
# 993       1  1_993     [0, 6]     [0, 0]           0
# 994       1  1_994     [1, 6]     [0, 0]           0
# 995       1  1_995  [1, 5, 9]  [0, 1, 0]           0
# 996       1  1_996  [0, 9, 3]  [0, 1, 0]           0
# 997       1  1_997  [5, 1, 0]  [1, 0, 1]           1
# 998       1  1_998     [9, 4]     [0, 0]           0
# 999       1  1_999     [5, 4]     [0, 0]           1

# %%
# Fit the model, A=10 as there are 10 different labelers
model = ClaraGibbs(burn_in=100, num_samples=100, sample_lag=3)
model.fit(A=10, R=2, ratings=np.array(df2.ratings))
# Out:
# INFO:gibbs:Fitting ...
# INFO:gibbs: N = 1000
# INFO:gibbs: R = 2
# INFO:gibbs: A = 10
# INFO:gibbs: C = 0
# INFO:gibbs:Initializing ...
# INFO:gibbs:Getting priors ...
# INFO:gibbs:  theta_scale = 1.0
# INFO:gibbs:  theta_mean = [0.72747547 0.27252453]
# INFO:gibbs: theta_prior = dimension = 2. scale = 1.0. mean = [0.72747547 0.27252453].
# INFO:gibbs:  psi_scale = [1.0, 1.0]
# INFO:gibbs:  psi_mean = [[0.75, 0.25], [0.25, 0.75]]
# INFO:gibbs: psi_prior = [dimension = 2. scale = 1.0. mean = [0.75 0.25]., dimension = 2. scale = 1.0. mean = [0.25 0.75].]
# INFO:gibbs: phi_prior = None
# INFO:gibbs:  llh = -1294.9583313254766
# INFO:gibbs:  theta = prior: dimension = 2. scale = 1.0. mean = [0.72747547 0.27252453].. data: counts: {1: 217, 0: 783}. count_sum = 1000.. posterior: [0.7829445309373945, 0.21705546906260556]
# INFO:gibbs:  psi[0][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 1566, 1: 176}. count_sum = 1742.. posterior: [0.898881239242685, 0.10111876075731498]
# INFO:gibbs:  psi[0][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {1: 434, 0: 64}. count_sum = 498.. posterior: [0.1287575150300601, 0.8712424849699398]
# INFO:gibbs:  psi[1][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[1][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[2][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[2][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[3][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[3][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[4][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[4][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[5][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[5][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[6][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[6][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[7][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[7][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[8][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[8][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[9][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[9][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:Sampling ...
# INFO:gibbs: Iter 0 / 400
# INFO:gibbs:  n_changes = 64 / 1000
# INFO:gibbs:  llh = -1429.8701455725163
# INFO:gibbs:  theta = prior: dimension = 2. scale = 1.0. mean = [0.72747547 0.27252453].. data: counts: {1: 181, 0: 819}. count_sum = 1000.. posterior: [0.8189085669014304, 0.1810914330985696]
# INFO:gibbs:  psi[0][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 1561, 1: 267}. count_sum = 1828.. posterior: [0.8538819026790596, 0.14611809732094042]
# INFO:gibbs:  psi[0][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {1: 343, 0: 69}. count_sum = 412.. posterior: [0.16767554479418886, 0.8323244552058111]
# INFO:gibbs:  psi[1][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[1][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[2][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[2][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[3][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[3][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[4][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[4][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[5][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[5][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[6][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[6][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[7][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[7][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[8][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[8][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[9][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[9][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs: Iter 40 / 400
# INFO:gibbs:  n_changes = 73 / 1000
# INFO:gibbs:  llh = -1393.019359723887
# INFO:gibbs:  theta = prior: dimension = 2. scale = 1.0. mean = [0.72747547 0.27252453].. data: counts: {1: 187, 0: 813}. count_sum = 1000.. posterior: [0.8129145609074244, 0.18708543909257558]
# INFO:gibbs:  psi[0][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 1571, 1: 251}. count_sum = 1822.. posterior: [0.8621777290181021, 0.13782227098189798]
# INFO:gibbs:  psi[0][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {1: 359, 0: 59}. count_sum = 418.. posterior: [0.14140811455847255, 0.8585918854415274]
# INFO:gibbs:  psi[1][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[1][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[2][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[2][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[3][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[3][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[4][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[4][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[5][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[5][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[6][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[6][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[7][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[7][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[8][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[8][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[9][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[9][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs: Iter 80 / 400
# INFO:gibbs:  n_changes = 78 / 1000
# INFO:gibbs:  llh = -1371.263696080491
# INFO:gibbs:  theta = prior: dimension = 2. scale = 1.0. mean = [0.72747547 0.27252453].. data: counts: {1: 175, 0: 825}. count_sum = 1000.. posterior: [0.8249025728954363, 0.17509742710456358]
# INFO:gibbs:  psi[0][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 1588, 1: 267}. count_sum = 1855.. posterior: [0.8560075431034483, 0.1439924568965517]
# INFO:gibbs:  psi[0][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {1: 343, 0: 42}. count_sum = 385.. posterior: [0.1094559585492228, 0.8905440414507773]
# INFO:gibbs:  psi[1][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[1][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[2][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[2][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[3][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[3][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[4][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[4][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[5][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[5][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[6][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[6][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[7][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[7][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[8][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[8][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[9][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[9][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs: Iter 120 / 400
# INFO:gibbs:  n_changes = 90 / 1000
# INFO:gibbs:  llh = -1422.9410554980382
# INFO:gibbs:  theta = prior: dimension = 2. scale = 1.0. mean = [0.72747547 0.27252453].. data: counts: {1: 175, 0: 825}. count_sum = 1000.. posterior: [0.8249025728954363, 0.17509742710456358]
# INFO:gibbs:  psi[0][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 1569, 1: 276}. count_sum = 1845.. posterior: [0.8503521126760564, 0.14964788732394366]
# INFO:gibbs:  psi[0][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {1: 334, 0: 61}. count_sum = 395.. posterior: [0.15467171717171718, 0.8453282828282829]
# INFO:gibbs:  psi[1][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[1][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[2][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[2][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[3][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[3][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[4][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[4][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[5][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[5][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[6][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[6][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[7][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[7][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[8][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[8][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[9][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[9][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs: Iter 160 / 400
# INFO:gibbs:  n_changes = 73 / 1000
# INFO:gibbs:  llh = -1362.3351195461764
# INFO:gibbs:  theta = prior: dimension = 2. scale = 1.0. mean = [0.72747547 0.27252453].. data: counts: {1: 154, 0: 846}. count_sum = 1000.. posterior: [0.8458815938744574, 0.15411840612554262]
# INFO:gibbs:  psi[0][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 1607, 1: 305}. count_sum = 1912.. posterior: [0.840433873497125, 0.15956612650287508]
# INFO:gibbs:  psi[0][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {1: 305, 0: 23}. count_sum = 328.. posterior: [0.07066869300911854, 0.9293313069908815]
# INFO:gibbs:  psi[1][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[1][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[2][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[2][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[3][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[3][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[4][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[4][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[5][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[5][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[6][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[6][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[7][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[7][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[8][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[8][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[9][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[9][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs: Iter 200 / 400
# INFO:gibbs:  n_changes = 78 / 1000
# INFO:gibbs:  llh = -1360.399625238528
# INFO:gibbs:  theta = prior: dimension = 2. scale = 1.0. mean = [0.72747547 0.27252453].. data: counts: {1: 159, 0: 841}. count_sum = 1000.. posterior: [0.8408865888794523, 0.1591134111205476]
# INFO:gibbs:  psi[0][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 1604, 1: 295}. count_sum = 1899.. posterior: [0.8446052631578947, 0.15539473684210525]
# INFO:gibbs:  psi[0][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {1: 315, 0: 26}. count_sum = 341.. posterior: [0.07675438596491228, 0.9232456140350878]
# INFO:gibbs:  psi[1][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[1][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[2][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[2][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[3][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[3][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[4][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[4][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[5][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[5][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[6][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[6][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[7][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[7][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[8][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[8][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[9][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[9][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs: Iter 240 / 400
# INFO:gibbs:  n_changes = 77 / 1000
# INFO:gibbs:  llh = -1367.401564979933
# INFO:gibbs:  theta = prior: dimension = 2. scale = 1.0. mean = [0.72747547 0.27252453].. data: counts: {1: 170, 0: 830}. count_sum = 1000.. posterior: [0.8298975778904414, 0.1701024221095586]
# INFO:gibbs:  psi[0][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 1593, 1: 275}. count_sum = 1868.. posterior: [0.8527287319422151, 0.1472712680577849]
# INFO:gibbs:  psi[0][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {1: 335, 0: 37}. count_sum = 372.. posterior: [0.09986595174262734, 0.9001340482573726]
# INFO:gibbs:  psi[1][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[1][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[2][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[2][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[3][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[3][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[4][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[4][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[5][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[5][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[6][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[6][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[7][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[7][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[8][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[8][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[9][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[9][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs: Iter 280 / 400
# INFO:gibbs:  n_changes = 53 / 1000
# INFO:gibbs:  llh = -1351.6562014671085
# INFO:gibbs:  theta = prior: dimension = 2. scale = 1.0. mean = [0.72747547 0.27252453].. data: counts: {1: 136, 0: 864}. count_sum = 1000.. posterior: [0.8638636118564753, 0.13613638814352463]
# INFO:gibbs:  psi[0][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 1620, 1: 338}. count_sum = 1958.. posterior: [0.8273353751914242, 0.1726646248085758]
# INFO:gibbs:  psi[0][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {1: 272, 0: 10}. count_sum = 282.. posterior: [0.036219081272084806, 0.9637809187279152]
# INFO:gibbs:  psi[1][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[1][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[2][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[2][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[3][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[3][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[4][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[4][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[5][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[5][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[6][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[6][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[7][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[7][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[8][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[8][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[9][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[9][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs: Iter 320 / 400
# INFO:gibbs:  n_changes = 89 / 1000
# INFO:gibbs:  llh = -1391.220814865598
# INFO:gibbs:  theta = prior: dimension = 2. scale = 1.0. mean = [0.72747547 0.27252453].. data: counts: {1: 169, 0: 831}. count_sum = 1000.. posterior: [0.8308965788894423, 0.1691034211105576]
# INFO:gibbs:  psi[0][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 1585, 1: 280}. count_sum = 1865.. posterior: [0.8498124330117899, 0.15018756698821006]
# INFO:gibbs:  psi[0][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {1: 330, 0: 45}. count_sum = 375.. posterior: [0.12034574468085106, 0.879654255319149]
# INFO:gibbs:  psi[1][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[1][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[2][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[2][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[3][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[3][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[4][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[4][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[5][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[5][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[6][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[6][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[7][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[7][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[8][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[8][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[9][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[9][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs: Iter 360 / 400
# INFO:gibbs:  n_changes = 91 / 1000
# INFO:gibbs:  llh = -1414.4434424628855
# INFO:gibbs:  theta = prior: dimension = 2. scale = 1.0. mean = [0.72747547 0.27252453].. data: counts: {1: 194, 0: 806}. count_sum = 1000.. posterior: [0.8059215539144174, 0.19407844608558258]
# INFO:gibbs:  psi[0][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 1556, 1: 243}. count_sum = 1799.. posterior: [0.8648611111111111, 0.1351388888888889]
# INFO:gibbs:  psi[0][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {1: 367, 0: 74}. count_sum = 441.. posterior: [0.16798642533936653, 0.8320135746606335]
# INFO:gibbs:  psi[1][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[1][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[2][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[2][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[3][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[3][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[4][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[4][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[5][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[5][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[6][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[6][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[7][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[7][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[8][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[8][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:  psi[9][0] = prior: dimension = 2. scale = 1.0. mean = [0.75 0.25].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.75, 0.25]
# INFO:gibbs:  psi[9][1] = prior: dimension = 2. scale = 1.0. mean = [0.25 0.75].. data: counts: {0: 0, 1: 0}. count_sum = 0.. posterior: [0.25, 0.75]
# INFO:gibbs:Done sampling!

# %%
# Get the prevalence estimate (mean and 95% confidence interval)
model.get_prevalence()
# Out:
# {'mean': [0.8244130624059257, 0.17558693759407412],
#  'ci': [[0.7924100654029289, 0.1429295949367314],
#   [0.8570704050632685, 0.20758993459707106]]}

# %%
# Get the confusion matrix for each labeler(mean and 95% confidence interval)
model.get_confusion_matrix(labeler_id=0)
# Out:
# [{'mean': [0.8542516807971826, 0.14574831920281758],
#   'ci': [[0.8321119809558635, 0.12599380774999952],
#    [0.8740061922500004, 0.16788801904413636]]},
#  {'mean': [0.12161179868106414, 0.8783882013189357],
#   'ci': [[0.053361260633318405, 0.8120007915748899],
#    [0.1879992084251101, 0.9466387393666816]]}]
